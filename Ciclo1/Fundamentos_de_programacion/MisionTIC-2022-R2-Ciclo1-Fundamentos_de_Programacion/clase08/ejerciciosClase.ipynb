# %%
# imprima los numeros primos del 1 al 100
for i in range(0,101):
    # print(i)
    for k in range(1,i+1):
        print(i,k)
        
        
semana_dic={'lunes':1,'martes':2,'miercoles':3,'jueves':4, 'viernes':5, 'sabado':6, 'domingo':7}
for semana in semana_dic:
    print(semana)

# %%
semana_dic={'lunes':1,'martes':2,'miercoles':3,'jueves':4, 'viernes':5, 'sabado':6, 'domingo':7}
for semana in semana_dic.items():
    print(semana)
# Out:
# ('lunes', 1)
# ('martes', 2)
# ('miercoles', 3)
# ('jueves', 4)
# ('viernes', 5)
# ('sabado', 6)
# ('domingo', 7)

# %%
# print(5%2)

for num in range(0,101):
    for n in range(1, num ):
        if (num%2!=0):
            print(num, 'es un numero primo')
# Out:
# 3 es un numero primo
# 3 es un numero primo
# 5 es un numero primo
# 5 es un numero primo
# 5 es un numero primo
# 5 es un numero primo
# 7 es un numero primo
# 7 es un numero primo
# 7 es un numero primo
# 7 es un numero primo
# 7 es un numero primo
# 7 es un numero primo
# 9 es un numero primo
# 9 es un numero primo
# 9 es un numero primo
# 9 es un numero primo
# 9 es un numero primo
# 9 es un numero primo
# 9 es un numero primo
# 9 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 11 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# 13 es un numero primo
# ...
